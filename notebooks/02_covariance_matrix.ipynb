# %%
import numpy as np
import matplotlib.pyplot as plt

print(np.__version__)

# %% [markdown]
# [2] p 315
#
# Two test methods to determine the dimension of the signal subspace proved to be
# most suitable for the spectral resolution methods, according to comparative inves-
# tigations [26,27].
# The diagonally loaded minimum description length (LMDL) criterion is
# derived from the estimated covariance matrix ^R þ aI. The load factor a can be
# chosen to be only 0.2, . . . , 2 times the receiver noise power level. Again we have
# N antenna or subarray channels. The number of used data snapshots is K. Then the
# following expression is formed by using the series of eigenvalues li in descending
# order
